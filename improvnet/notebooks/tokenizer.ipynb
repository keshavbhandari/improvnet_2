# %% [markdown]
# ## Test Tokenizer

# %%
from improvnet.tokenizer.midi import MidiDict, dict_to_midi
from improvnet.tokenizer.absolute import AbsTokenizer

tokenizer = AbsTokenizer()
# filepath = "/data/home/acw769/improvnet_2/improvnet/notebooks/beethoven_string-trio_3_6_(nc)wittenburg.mid"
filepath = "/data/home/acw769/improvnet_2/improvnet/notebooks/2_marche.mid"
midi_dict = MidiDict.from_midi(filepath)
tokens = tokenizer.tokenize(midi_dict)
print(len(tokens))
tokens
# Out:
# 3480
# [('<S>', '<S>', '<S>', '<S>', '<S>'),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 530),
#   ('dur', 110)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 550),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 550),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 550),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 550),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 650),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 680),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 680),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 680),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 680),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 47),
#   ('velocity', 60),
#   ('onset', 1710),
#   ('dur', 140)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 1710),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 750)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3960),
#   ('dur', 110)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3980),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3980),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 3980),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3980),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4080),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4110),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4110),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4110),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4110),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4710),
#   ('dur', 210)),
#  ('<T>', '<T>', '<T>', '<T>', '<T>'),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 47),
#   ('velocity', 60),
#   ('onset', 140),
#   ('dur', 140)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1000),
#   ('dur', 750)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 1750),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1860),
#   ('dur', 1290)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1860),
#   ('dur', 1180)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 1860),
#   ('dur', 1180)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 72),
#   ('velocity', 60),
#   ('onset', 1860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 33),
#   ('velocity', 40),
#   ('onset', 1860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 40),
#   ('onset', 1860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1860),
#   ('dur', 1290)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 32),
#   ('velocity', 40),
#   ('onset', 2070),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 44),
#   ('velocity', 40),
#   ('onset', 2070),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 74),
#   ('velocity', 60),
#   ('onset', 2180),
#   ('dur', 110)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 72),
#   ('velocity', 60),
#   ('onset', 2290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 33),
#   ('velocity', 40),
#   ('onset', 2290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 40),
#   ('onset', 2290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 35),
#   ('velocity', 40),
#   ('onset', 2500),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 40),
#   ('onset', 2500),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 60),
#   ('onset', 2610),
#   ('dur', 110)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 69),
#   ('velocity', 60),
#   ('onset', 2710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 36),
#   ('velocity', 40),
#   ('onset', 2710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 48),
#   ('velocity', 40),
#   ('onset', 2710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 37),
#   ('velocity', 40),
#   ('onset', 2930),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 49),
#   ('velocity', 40),
#   ('onset', 2930),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 60),
#   ('onset', 3040),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 57),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 60),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 57),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 60),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 38),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 50),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 30),
#   ('velocity', 40),
#   ('onset', 3360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 42),
#   ('velocity', 40),
#   ('onset', 3360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 62),
#   ('velocity', 60),
#   ('onset', 3460),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3570),
#   ('dur', 1290)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3570),
#   ('dur', 1180)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 60),
#   ('onset', 3570),
#   ('dur', 1180)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 60),
#   ('onset', 3570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 31),
#   ('velocity', 40),
#   ('onset', 3570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 43),
#   ('velocity', 40),
#   ('onset', 3570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3570),
#   ('dur', 1290)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 30),
#   ('velocity', 40),
#   ('onset', 3790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 42),
#   ('velocity', 40),
#   ('onset', 3790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 72),
#   ('velocity', 60),
#   ('onset', 3890),
#   ('dur', 110)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 60),
#   ('onset', 4000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 31),
#   ('velocity', 40),
#   ('onset', 4000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 43),
#   ('velocity', 40),
#   ('onset', 4000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 33),
#   ('velocity', 40),
#   ('onset', 4210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 40),
#   ('onset', 4210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 69),
#   ('velocity', 60),
#   ('onset', 4320),
#   ('dur', 110)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 60),
#   ('onset', 4430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 34),
#   ('velocity', 40),
#   ('onset', 4430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 46),
#   ('velocity', 40),
#   ('onset', 4430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 35),
#   ('velocity', 40),
#   ('onset', 4640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 40),
#   ('onset', 4640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 60),
#   ('onset', 4750),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 55),
#   ('velocity', 60),
#   ('onset', 4860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 60),
#   ('onset', 4860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 55),
#   ('velocity', 60),
#   ('onset', 4860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 4860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 36),
#   ('velocity', 40),
#   ('onset', 4860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 48),
#   ('velocity', 40),
#   ('onset', 4860),
#   ('dur', 210)),
#  ('<T>', '<T>', '<T>', '<T>', '<T>'),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 28),
#   ('velocity', 40),
#   ('onset', 70),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 40),
#   ('velocity', 40),
#   ('onset', 70),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 60),
#   ('onset', 180),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 60),
#   ('velocity', 60),
#   ('onset', 290),
#   ('dur', 430)),
#  (('instrument', 'Tuba'),
#   ('pitch', 60),
#   ('velocity', 60),
#   ('onset', 290),
#   ('dur', 430)),
#  (('instrument', 'Tuba'),
#   ('pitch', 60),
#   ('velocity', 60),
#   ('onset', 290),
#   ('dur', 430)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 60),
#   ('onset', 290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 33),
#   ('velocity', 40),
#   ('onset', 290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 40),
#   ('onset', 290),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 60),
#   ('velocity', 60),
#   ('onset', 290),
#   ('dur', 430)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 34),
#   ('velocity', 50),
#   ('onset', 500),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 46),
#   ('velocity', 50),
#   ('onset', 500),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 610),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 54),
#   ('velocity', 60),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 60),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 54),
#   ('velocity', 60),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 63),
#   ('velocity', 60),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 35),
#   ('velocity', 50),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 50),
#   ('onset', 710),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 36),
#   ('velocity', 60),
#   ('onset', 930),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 48),
#   ('velocity', 60),
#   ('onset', 930),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 1040),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 57),
#   ('velocity', 70),
#   ('onset', 1140),
#   ('dur', 430)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 60),
#   ('onset', 1140),
#   ('dur', 430)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 70),
#   ('onset', 1140),
#   ('dur', 430)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 70),
#   ('onset', 1140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 37),
#   ('velocity', 60),
#   ('onset', 1140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 49),
#   ('velocity', 60),
#   ('onset', 1140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 57),
#   ('velocity', 70),
#   ('onset', 1140),
#   ('dur', 430)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 39),
#   ('velocity', 60),
#   ('onset', 1360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 51),
#   ('velocity', 60),
#   ('onset', 1360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 80),
#   ('onset', 1460),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 55),
#   ('velocity', 70),
#   ('onset', 1570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 55),
#   ('velocity', 70),
#   ('onset', 1570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 80),
#   ('onset', 1570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 40),
#   ('velocity', 70),
#   ('onset', 1570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 52),
#   ('velocity', 70),
#   ('onset', 1570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 55),
#   ('velocity', 70),
#   ('onset', 1790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 43),
#   ('velocity', 70),
#   ('onset', 1790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 1890),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 64),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 860)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 2000),
#   ('dur', 860)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 1070)),
#  (('instrument', 'Tuba'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 1070)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 57),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 72),
#   ('velocity', 90),
#   ('onset', 2000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 70),
#   ('onset', 2000),
#   ('dur', 860)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 59),
#   ('velocity', 70),
#   ('onset', 2210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 70),
#   ('onset', 2210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 2320),
#   ('dur', 110)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 60),
#   ('velocity', 70),
#   ('onset', 2430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 69),
#   ('velocity', 90),
#   ('onset', 2430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 48),
#   ('velocity', 70),
#   ('onset', 2430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 61),
#   ('velocity', 70),
#   ('onset', 2640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 49),
#   ('velocity', 70),
#   ('onset', 2640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 90),
#   ('onset', 2750),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 60),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 62),
#   ('velocity', 70),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 74),
#   ('velocity', 90),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 50),
#   ('velocity', 70),
#   ('onset', 2860),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 81),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 86),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 190)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 81),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 78),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 81),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 69),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 90),
#   ('onset', 3290),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 83),
#   ('velocity', 90),
#   ('onset', 3320),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 84),
#   ('velocity', 90),
#   ('onset', 3380),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 85),
#   ('velocity', 90),
#   ('onset', 3410),
#   ('dur', 90)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 3710),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4140),
#   ('dur', 100)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4250),
#   ('dur', 110)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4270),
#   ('dur', 120)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4270),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4270),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4270),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4370),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4390),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 4390),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4390),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4390),
#   ('dur', 170)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 4570),
#   ('dur', 210)),
#  ('<T>', '<T>', '<T>', '<T>', '<T>'),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 0),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 47),
#   ('velocity', 60),
#   ('onset', 430),
#   ('dur', 140)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 78),
#   ('velocity', 40),
#   ('onset', 430),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 62),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 860),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 40),
#   ('onset', 1290),
#   ('dur', 750)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 74),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2140),
# ...
#   ('pitch', 60),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 72),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 48),
#   ('velocity', 40),
#   ('onset', 2140),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 2180),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 2180),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 64),
#   ('velocity', 70),
#   ('onset', 2190),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 2190),
#   ('dur', 330)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 2360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 71),
#   ('velocity', 40),
#   ('onset', 2360),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 40),
#   ('onset', 2360),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 71),
#   ('velocity', 70),
#   ('onset', 2570),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2570),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 70),
#   ('onset', 2570),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 71),
#   ('velocity', 70),
#   ('onset', 2570),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2570),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 57),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 69),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 45),
#   ('velocity', 40),
#   ('onset', 2570),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 72),
#   ('velocity', 70),
#   ('onset', 2610),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 72),
#   ('velocity', 70),
#   ('onset', 2610),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2620),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 72),
#   ('velocity', 70),
#   ('onset', 2620),
#   ('dur', 330)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 55),
#   ('velocity', 40),
#   ('onset', 2790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 67),
#   ('velocity', 40),
#   ('onset', 2790),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 43),
#   ('velocity', 40),
#   ('onset', 2790),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 75),
#   ('velocity', 80),
#   ('onset', 3000),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 72),
#   ('velocity', 80),
#   ('onset', 3000),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 75),
#   ('velocity', 80),
#   ('onset', 3000),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 63),
#   ('velocity', 80),
#   ('onset', 3000),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 60),
#   ('velocity', 80),
#   ('onset', 3000),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 54),
#   ('velocity', 40),
#   ('onset', 3000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 66),
#   ('velocity', 40),
#   ('onset', 3000),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 42),
#   ('velocity', 40),
#   ('onset', 3000),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 76),
#   ('velocity', 80),
#   ('onset', 3040),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 64),
#   ('velocity', 80),
#   ('onset', 3040),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 72),
#   ('velocity', 80),
#   ('onset', 3050),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 76),
#   ('velocity', 80),
#   ('onset', 3050),
#   ('dur', 330)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 64),
#   ('velocity', 40),
#   ('onset', 3210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 40),
#   ('velocity', 40),
#   ('onset', 3210),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 52),
#   ('velocity', 40),
#   ('onset', 3210),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 77),
#   ('velocity', 80),
#   ('onset', 3430),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 71),
#   ('velocity', 80),
#   ('onset', 3430),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 77),
#   ('velocity', 80),
#   ('onset', 3430),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 65),
#   ('velocity', 80),
#   ('onset', 3430),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 59),
#   ('velocity', 80),
#   ('onset', 3430),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 63),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 39),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 51),
#   ('velocity', 40),
#   ('onset', 3430),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 78),
#   ('velocity', 80),
#   ('onset', 3460),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 66),
#   ('velocity', 80),
#   ('onset', 3460),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 71),
#   ('velocity', 80),
#   ('onset', 3470),
#   ('dur', 330)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 80),
#   ('onset', 3470),
#   ('dur', 330)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 61),
#   ('velocity', 40),
#   ('onset', 3640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 37),
#   ('velocity', 40),
#   ('onset', 3640),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 49),
#   ('velocity', 40),
#   ('onset', 3640),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 82),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 40)),
#  (('instrument', 'Flute'),
#   ('pitch', 75),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 200)),
#  (('instrument', 'Oboe'),
#   ('pitch', 75),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 210)),
#  (('instrument', 'Oboe'),
#   ('pitch', 78),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 210)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 70),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 40)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 3860),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 59),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 35),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 210)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 40),
#   ('onset', 3860),
#   ('dur', 210)),
#  (('instrument', 'Flute'),
#   ('pitch', 83),
#   ('velocity', 90),
#   ('onset', 3890),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 3890),
#   ('dur', 330)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 4290),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 4710),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4820),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 4820),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4820),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4820),
#   ('dur', 110)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 4820),
#   ('dur', 110)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4840),
#   ('dur', 120)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4840),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4940),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 4940),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4940),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4940),
#   ('dur', 200)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 90),
#   ('onset', 4940),
#   ('dur', 200)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 4960),
#   ('dur', 170)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 63),
#   ('velocity', 90),
#   ('onset', 4960),
#   ('dur', 170)),
#  ('<T>', '<T>', '<T>', '<T>', '<T>'),
#  (('instrument', 'Bassoon'),
#   ('pitch', 52),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 64),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 52),
#   ('velocity', 90),
#   ('onset', 140),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 55),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 90),
#   ('onset', 570),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 45),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 48),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 55),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 60),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 45),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 52),
#   ('velocity', 90),
#   ('onset', 1000),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 42),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 48),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 57),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 60),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 45),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Tuba'),
#   ('pitch', 52),
#   ('velocity', 90),
#   ('onset', 1430),
#   ('dur', 210)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 39),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 640)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 47),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 640)),
#  (('instrument', 'Tuba'),
#   ('pitch', 59),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 160)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 620)),
#  (('instrument', 'Tuba'),
#   ('pitch', 54),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 620)),
#  (('instrument', 'Tuba'),
#   ('pitch', 47),
#   ('velocity', 90),
#   ('onset', 1860),
#   ('dur', 640)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 83),
#   ('velocity', 70),
#   ('onset', 2030),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 71),
#   ('velocity', 70),
#   ('onset', 2030),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 82),
#   ('velocity', 70),
#   ('onset', 2290),
#   ('dur', 30)),
#  (('instrument', 'Tuba'),
#   ('pitch', 70),
#   ('velocity', 70),
#   ('onset', 2290),
#   ('dur', 30)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 50),
#   ('velocity', 40),
#   ('onset', 2290),
#   ('dur', 40)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 35),
#   ('velocity', 40),
#   ('onset', 2290),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 42),
#   ('velocity', 40),
#   ('onset', 2290),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 51),
#   ('velocity', 40),
#   ('onset', 2320),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 81),
#   ('velocity', 70),
#   ('onset', 2450),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 69),
#   ('velocity', 70),
#   ('onset', 2450),
#   ('dur', 120)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 79),
#   ('velocity', 70),
#   ('onset', 2710),
#   ('dur', 30)),
#  (('instrument', 'Tuba'),
#   ('pitch', 67),
#   ('velocity', 70),
#   ('onset', 2710),
#   ('dur', 30)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 51),
#   ('velocity', 40),
#   ('onset', 2710),
#   ('dur', 40)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 40),
#   ('velocity', 40),
#   ('onset', 2710),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 47),
#   ('velocity', 40),
#   ('onset', 2710),
#   ('dur', 200)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 52),
#   ('velocity', 40),
#   ('onset', 2750),
#   ('dur', 330)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 78),
#   ('velocity', 70),
#   ('onset', 2880),
#   ('dur', 120)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 80),
#   ('onset', 2880),
#   ('dur', 90)),
#  (('instrument', 'Tuba'),
#   ('pitch', 78),
#   ('velocity', 80),
#   ('onset', 2880),
#   ('dur', 90)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 66),
#   ('velocity', 70),
#   ('onset', 2900),
#   ('dur', 100)),
#  (('instrument', 'Tuba'),
#   ('pitch', 66),
#   ('velocity', 60),
#   ('onset', 2900),
#   ('dur', 70)),
#  (('instrument', 'Clarinet'),
#   ('pitch', 76),
#   ('velocity', 70),
#   ('onset', 3140),
#   ('dur', 30)),
#  (('instrument', 'Bassoon'),
#   ('pitch', 64),
#   ('velocity', 70),
#   ('onset', 3140),
#   ('dur', 40)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 80),
#   ('onset', 3140),
#   ('dur', 30)),
#  (('instrument', 'Tuba'),
#   ('pitch', 64),
#   ('velocity', 60),
#   ('onset', 3140),
#   ('dur', 30)),
#  (('instrument', 'Tuba'),
#   ('pitch', 76),
#   ('velocity', 80),
#   ('onset', 3140),
#   ('dur', 30)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 58),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 40)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 58),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 40)),
#  (('instrument', 'String Ensemble'),
#   ('pitch', 43),
#   ('velocity', 40),
#   ('onset', 3140),
#   ('dur', 210)),
#  ...]

# %%
from improvnet.utils.utils import ProcessData

processor = ProcessData()

# %%
len(processor.tokenizer.compound_vocab['duration'])
# Out:
# 510

# %%
processor.tokenizer.compound_vocab.keys()
# Out:
# dict_keys(['instrument', 'pitch', 'velocity', 'onset', 'duration', 'genre', 'form'])

# %%
[len(v) for v in processor.tokenizer.compound_vocab.values()]
# Out:
# [91, 137, 22, 509, 510, 13, 40]

# %%
# detokenized_midi_dict = tokenizer.detokenize(tokens[3:])
# detokenized_midi_dict_out = midi_dict.to_midi()
# detokenized_midi_dict_out.save("reconstructed.mid")

# %%
detokenized_midi_dict = tokenizer.detokenize(tokens)
detokenized_midi_dict_out = midi_dict.to_midi()
detokenized_midi_dict_out.save("reconstructed.mid")

# %%
from improvnet.utils.utils import ProcessData

processor = ProcessData()

corrupted_main_dict, corrupted_accom_dict, mask_main_tensor, mask_accom_tensor, original_main_dict, original_accom_dict, genre_token, form_token = processor.pretraining_pipeline(filepath, corruption_type='onset_duration_mask', random_ratio=0.5, genre='classical', form='unknown', segment_length=1024)

# %%
corrupted_main_dict
# Out:
# {'instrument': tensor([49,  9,  0, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90,
#          90, 90, 90, 90, 90, 90, 90, 90, 90, 90,  5, 90, 90, 90, 90, 90, 90, 90,
#          90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90,  5, 90,
#          90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90, 90,
#          90, 90, 90, 90, 90, 90,  5, 90, 90,  1]),
#  'pitch': tensor([ 8,  8,  0, 52, 62, 65, 67, 62, 65, 52, 52, 62, 65, 67, 62, 65, 52, 52,
#          62, 67, 62, 65, 52, 52, 62, 67, 62, 65,  5, 52, 62, 65, 67, 62, 65, 52,
#          52, 62, 65, 67, 62, 65, 52, 52, 62, 67, 62, 65, 52, 52, 62, 67,  5, 62,
#          65, 52, 62, 65, 67, 62, 65, 52, 52, 62, 65, 67, 62, 65, 52, 52, 62, 67,
#          62, 65, 52, 52, 62, 67,  5, 62, 65,  1]),
#  'velocity': tensor([8, 8, 0, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9,
#          9, 9, 9, 9, 5, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9,
#          9, 9, 9, 9, 5, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9,
#          9, 9, 9, 9, 9, 9, 5, 9, 9, 1]),
#  'onset': tensor([  8,   8,   0,   9,   9,   9,   9,  76,  76, 109, 142, 142, 142, 142,
#          209, 209,   6, 276, 276, 276, 342,   6, 376, 409, 409, 409, 476, 476,
#            5,  42,  42,  42,  42,   6, 109, 142, 176, 176,   6, 176, 242, 242,
#          276,   6, 309,   6, 376, 376, 409, 442, 442, 442,   5,   9,   6,  76,
#            6,   6,   6, 142,   6, 176, 209, 209,   6, 209,   6,   6,   6, 342,
#          342, 342, 409,   6,   6, 476,   6,   6,   5,  42,  42,   1]),
#  'duration': tensor([8, 8, 0, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 6, 9, 9, 9, 9, 6, 9, 9,
#          9, 9, 9, 9, 5, 9, 9, 9, 9, 6, 9, 9, 9, 9, 6, 9, 9, 9, 9, 6, 9, 6, 9, 9,
#          9, 9, 9, 9, 5, 9, 6, 9, 6, 6, 6, 9, 6, 9, 9, 9, 6, 9, 6, 6, 6, 9, 9, 9,
#          9, 6, 6, 9, 6, 6, 5, 9, 9, 1])}

# %%
# # Write back to midi to verify correctness
# detokenized_midi_dict = tokenizer.detokenize(token_dict)
# detokenized_midi_dict_out = midi_dict.to_midi()
# detokenized_midi_dict_out.save("/keshav/improvnet_2/improvnet/notebooks/reconstructed.mid")

# %%
print(len(tokenizer.compound_vocab['instrument']), len(tokenizer.compound_vocab['pitch']), len(tokenizer.compound_vocab['velocity']), len(tokenizer.compound_vocab['onset']), len(tokenizer.compound_vocab['duration']))
print(tokenizer.compound_vocab.keys())
# Out:
# 91 137 22 509 510
# dict_keys(['instrument', 'pitch', 'velocity', 'onset', 'duration', 'genre', 'form'])

# %%
tokenizer.tok_to_id_duration
# Out:
# {'<S>': 0,
#  '<E>': 1,
#  '<P>': 2,
#  '<U>': 3,
#  '<D>': 4,
#  '<T>': 5,
#  '<MASK>': 6,
#  '<SEP>': 7,
#  '<BLANK>': 8,
#  ('dur', 0): 9,
#  ('dur', 10): 10,
#  ('dur', 20): 11,
#  ('dur', 30): 12,
#  ('dur', 40): 13,
#  ('dur', 50): 14,
#  ('dur', 60): 15,
#  ('dur', 70): 16,
#  ('dur', 80): 17,
#  ('dur', 90): 18,
#  ('dur', 100): 19,
#  ('dur', 110): 20,
#  ('dur', 120): 21,
#  ('dur', 130): 22,
#  ('dur', 140): 23,
#  ('dur', 150): 24,
#  ('dur', 160): 25,
#  ('dur', 170): 26,
#  ('dur', 180): 27,
#  ('dur', 190): 28,
#  ('dur', 200): 29,
#  ('dur', 210): 30,
#  ('dur', 220): 31,
#  ('dur', 230): 32,
#  ('dur', 240): 33,
#  ('dur', 250): 34,
#  ('dur', 260): 35,
#  ('dur', 270): 36,
#  ('dur', 280): 37,
#  ('dur', 290): 38,
#  ('dur', 300): 39,
#  ('dur', 310): 40,
#  ('dur', 320): 41,
#  ('dur', 330): 42,
#  ('dur', 340): 43,
#  ('dur', 350): 44,
#  ('dur', 360): 45,
#  ('dur', 370): 46,
#  ('dur', 380): 47,
#  ('dur', 390): 48,
#  ('dur', 400): 49,
#  ('dur', 410): 50,
#  ('dur', 420): 51,
#  ('dur', 430): 52,
#  ('dur', 440): 53,
#  ('dur', 450): 54,
#  ('dur', 460): 55,
#  ('dur', 470): 56,
#  ('dur', 480): 57,
#  ('dur', 490): 58,
#  ('dur', 500): 59,
#  ('dur', 510): 60,
#  ('dur', 520): 61,
#  ('dur', 530): 62,
#  ('dur', 540): 63,
#  ('dur', 550): 64,
#  ('dur', 560): 65,
#  ('dur', 570): 66,
#  ('dur', 580): 67,
#  ('dur', 590): 68,
#  ('dur', 600): 69,
#  ('dur', 610): 70,
#  ('dur', 620): 71,
#  ('dur', 630): 72,
#  ('dur', 640): 73,
#  ('dur', 650): 74,
#  ('dur', 660): 75,
#  ('dur', 670): 76,
#  ('dur', 680): 77,
#  ('dur', 690): 78,
#  ('dur', 700): 79,
#  ('dur', 710): 80,
#  ('dur', 720): 81,
#  ('dur', 730): 82,
#  ('dur', 740): 83,
#  ('dur', 750): 84,
#  ('dur', 760): 85,
#  ('dur', 770): 86,
#  ('dur', 780): 87,
#  ('dur', 790): 88,
#  ('dur', 800): 89,
#  ('dur', 810): 90,
#  ('dur', 820): 91,
#  ('dur', 830): 92,
#  ('dur', 840): 93,
#  ('dur', 850): 94,
#  ('dur', 860): 95,
#  ('dur', 870): 96,
#  ('dur', 880): 97,
#  ('dur', 890): 98,
#  ('dur', 900): 99,
#  ('dur', 910): 100,
#  ('dur', 920): 101,
#  ('dur', 930): 102,
#  ('dur', 940): 103,
#  ('dur', 950): 104,
#  ('dur', 960): 105,
#  ('dur', 970): 106,
#  ('dur', 980): 107,
#  ('dur', 990): 108,
#  ('dur', 1000): 109,
#  ('dur', 1010): 110,
#  ('dur', 1020): 111,
#  ('dur', 1030): 112,
#  ('dur', 1040): 113,
#  ('dur', 1050): 114,
#  ('dur', 1060): 115,
#  ('dur', 1070): 116,
#  ('dur', 1080): 117,
#  ('dur', 1090): 118,
#  ('dur', 1100): 119,
#  ('dur', 1110): 120,
#  ('dur', 1120): 121,
#  ('dur', 1130): 122,
#  ('dur', 1140): 123,
#  ('dur', 1150): 124,
#  ('dur', 1160): 125,
#  ('dur', 1170): 126,
#  ('dur', 1180): 127,
#  ('dur', 1190): 128,
#  ('dur', 1200): 129,
#  ('dur', 1210): 130,
#  ('dur', 1220): 131,
#  ('dur', 1230): 132,
#  ('dur', 1240): 133,
#  ('dur', 1250): 134,
#  ('dur', 1260): 135,
#  ('dur', 1270): 136,
#  ('dur', 1280): 137,
#  ('dur', 1290): 138,
#  ('dur', 1300): 139,
#  ('dur', 1310): 140,
#  ('dur', 1320): 141,
#  ('dur', 1330): 142,
#  ('dur', 1340): 143,
#  ('dur', 1350): 144,
#  ('dur', 1360): 145,
#  ('dur', 1370): 146,
#  ('dur', 1380): 147,
#  ('dur', 1390): 148,
#  ('dur', 1400): 149,
#  ('dur', 1410): 150,
#  ('dur', 1420): 151,
#  ('dur', 1430): 152,
#  ('dur', 1440): 153,
#  ('dur', 1450): 154,
#  ('dur', 1460): 155,
#  ('dur', 1470): 156,
#  ('dur', 1480): 157,
#  ('dur', 1490): 158,
#  ('dur', 1500): 159,
#  ('dur', 1510): 160,
#  ('dur', 1520): 161,
#  ('dur', 1530): 162,
#  ('dur', 1540): 163,
#  ('dur', 1550): 164,
#  ('dur', 1560): 165,
#  ('dur', 1570): 166,
#  ('dur', 1580): 167,
#  ('dur', 1590): 168,
#  ('dur', 1600): 169,
#  ('dur', 1610): 170,
#  ('dur', 1620): 171,
#  ('dur', 1630): 172,
#  ('dur', 1640): 173,
#  ('dur', 1650): 174,
#  ('dur', 1660): 175,
#  ('dur', 1670): 176,
#  ('dur', 1680): 177,
#  ('dur', 1690): 178,
#  ('dur', 1700): 179,
#  ('dur', 1710): 180,
#  ('dur', 1720): 181,
#  ('dur', 1730): 182,
#  ('dur', 1740): 183,
#  ('dur', 1750): 184,
#  ('dur', 1760): 185,
#  ('dur', 1770): 186,
#  ('dur', 1780): 187,
#  ('dur', 1790): 188,
#  ('dur', 1800): 189,
#  ('dur', 1810): 190,
#  ('dur', 1820): 191,
#  ('dur', 1830): 192,
#  ('dur', 1840): 193,
#  ('dur', 1850): 194,
#  ('dur', 1860): 195,
#  ('dur', 1870): 196,
#  ('dur', 1880): 197,
#  ('dur', 1890): 198,
#  ('dur', 1900): 199,
#  ('dur', 1910): 200,
#  ('dur', 1920): 201,
#  ('dur', 1930): 202,
#  ('dur', 1940): 203,
#  ('dur', 1950): 204,
#  ('dur', 1960): 205,
#  ('dur', 1970): 206,
#  ('dur', 1980): 207,
#  ('dur', 1990): 208,
#  ('dur', 2000): 209,
#  ('dur', 2010): 210,
#  ('dur', 2020): 211,
#  ('dur', 2030): 212,
#  ('dur', 2040): 213,
#  ('dur', 2050): 214,
#  ('dur', 2060): 215,
#  ('dur', 2070): 216,
#  ('dur', 2080): 217,
#  ('dur', 2090): 218,
#  ('dur', 2100): 219,
#  ('dur', 2110): 220,
#  ('dur', 2120): 221,
#  ('dur', 2130): 222,
#  ('dur', 2140): 223,
#  ('dur', 2150): 224,
#  ('dur', 2160): 225,
#  ('dur', 2170): 226,
#  ('dur', 2180): 227,
#  ('dur', 2190): 228,
#  ('dur', 2200): 229,
#  ('dur', 2210): 230,
#  ('dur', 2220): 231,
#  ('dur', 2230): 232,
#  ('dur', 2240): 233,
#  ('dur', 2250): 234,
#  ('dur', 2260): 235,
#  ('dur', 2270): 236,
#  ('dur', 2280): 237,
#  ('dur', 2290): 238,
#  ('dur', 2300): 239,
#  ('dur', 2310): 240,
#  ('dur', 2320): 241,
#  ('dur', 2330): 242,
#  ('dur', 2340): 243,
#  ('dur', 2350): 244,
#  ('dur', 2360): 245,
#  ('dur', 2370): 246,
#  ('dur', 2380): 247,
#  ('dur', 2390): 248,
#  ('dur', 2400): 249,
#  ('dur', 2410): 250,
#  ('dur', 2420): 251,
#  ('dur', 2430): 252,
#  ('dur', 2440): 253,
#  ('dur', 2450): 254,
#  ('dur', 2460): 255,
#  ('dur', 2470): 256,
#  ('dur', 2480): 257,
#  ('dur', 2490): 258,
#  ('dur', 2500): 259,
#  ('dur', 2510): 260,
#  ('dur', 2520): 261,
#  ('dur', 2530): 262,
#  ('dur', 2540): 263,
#  ('dur', 2550): 264,
#  ('dur', 2560): 265,
#  ('dur', 2570): 266,
#  ('dur', 2580): 267,
#  ('dur', 2590): 268,
#  ('dur', 2600): 269,
#  ('dur', 2610): 270,
#  ('dur', 2620): 271,
#  ('dur', 2630): 272,
#  ('dur', 2640): 273,
#  ('dur', 2650): 274,
#  ('dur', 2660): 275,
#  ('dur', 2670): 276,
#  ('dur', 2680): 277,
#  ('dur', 2690): 278,
#  ('dur', 2700): 279,
#  ('dur', 2710): 280,
#  ('dur', 2720): 281,
#  ('dur', 2730): 282,
#  ('dur', 2740): 283,
#  ('dur', 2750): 284,
#  ('dur', 2760): 285,
#  ('dur', 2770): 286,
#  ('dur', 2780): 287,
#  ('dur', 2790): 288,
#  ('dur', 2800): 289,
#  ('dur', 2810): 290,
#  ('dur', 2820): 291,
#  ('dur', 2830): 292,
#  ('dur', 2840): 293,
#  ('dur', 2850): 294,
#  ('dur', 2860): 295,
#  ('dur', 2870): 296,
#  ('dur', 2880): 297,
#  ('dur', 2890): 298,
#  ('dur', 2900): 299,
#  ('dur', 2910): 300,
#  ('dur', 2920): 301,
#  ('dur', 2930): 302,
#  ('dur', 2940): 303,
#  ('dur', 2950): 304,
#  ('dur', 2960): 305,
#  ('dur', 2970): 306,
#  ('dur', 2980): 307,
#  ('dur', 2990): 308,
#  ('dur', 3000): 309,
#  ('dur', 3010): 310,
#  ('dur', 3020): 311,
#  ('dur', 3030): 312,
#  ('dur', 3040): 313,
#  ('dur', 3050): 314,
#  ('dur', 3060): 315,
#  ('dur', 3070): 316,
#  ('dur', 3080): 317,
#  ('dur', 3090): 318,
#  ('dur', 3100): 319,
#  ('dur', 3110): 320,
#  ('dur', 3120): 321,
#  ('dur', 3130): 322,
#  ('dur', 3140): 323,
#  ('dur', 3150): 324,
#  ('dur', 3160): 325,
#  ('dur', 3170): 326,
#  ('dur', 3180): 327,
#  ('dur', 3190): 328,
#  ('dur', 3200): 329,
#  ('dur', 3210): 330,
#  ('dur', 3220): 331,
#  ('dur', 3230): 332,
#  ('dur', 3240): 333,
#  ('dur', 3250): 334,
#  ('dur', 3260): 335,
#  ('dur', 3270): 336,
#  ('dur', 3280): 337,
#  ('dur', 3290): 338,
#  ('dur', 3300): 339,
#  ('dur', 3310): 340,
#  ('dur', 3320): 341,
#  ('dur', 3330): 342,
#  ('dur', 3340): 343,
#  ('dur', 3350): 344,
#  ('dur', 3360): 345,
#  ('dur', 3370): 346,
#  ('dur', 3380): 347,
#  ('dur', 3390): 348,
#  ('dur', 3400): 349,
#  ('dur', 3410): 350,
#  ('dur', 3420): 351,
#  ('dur', 3430): 352,
#  ('dur', 3440): 353,
#  ('dur', 3450): 354,
#  ('dur', 3460): 355,
#  ('dur', 3470): 356,
#  ('dur', 3480): 357,
#  ('dur', 3490): 358,
#  ('dur', 3500): 359,
#  ('dur', 3510): 360,
#  ('dur', 3520): 361,
#  ('dur', 3530): 362,
#  ('dur', 3540): 363,
#  ('dur', 3550): 364,
#  ('dur', 3560): 365,
#  ('dur', 3570): 366,
#  ('dur', 3580): 367,
#  ('dur', 3590): 368,
#  ('dur', 3600): 369,
#  ('dur', 3610): 370,
#  ('dur', 3620): 371,
#  ('dur', 3630): 372,
#  ('dur', 3640): 373,
#  ('dur', 3650): 374,
#  ('dur', 3660): 375,
#  ('dur', 3670): 376,
#  ('dur', 3680): 377,
#  ('dur', 3690): 378,
#  ('dur', 3700): 379,
#  ('dur', 3710): 380,
#  ('dur', 3720): 381,
#  ('dur', 3730): 382,
#  ('dur', 3740): 383,
#  ('dur', 3750): 384,
#  ('dur', 3760): 385,
#  ('dur', 3770): 386,
#  ('dur', 3780): 387,
#  ('dur', 3790): 388,
#  ('dur', 3800): 389,
#  ('dur', 3810): 390,
#  ('dur', 3820): 391,
#  ('dur', 3830): 392,
#  ('dur', 3840): 393,
#  ('dur', 3850): 394,
#  ('dur', 3860): 395,
#  ('dur', 3870): 396,
#  ('dur', 3880): 397,
#  ('dur', 3890): 398,
#  ('dur', 3900): 399,
#  ('dur', 3910): 400,
#  ('dur', 3920): 401,
#  ('dur', 3930): 402,
#  ('dur', 3940): 403,
#  ('dur', 3950): 404,
#  ('dur', 3960): 405,
#  ('dur', 3970): 406,
#  ('dur', 3980): 407,
#  ('dur', 3990): 408,
#  ('dur', 4000): 409,
#  ('dur', 4010): 410,
#  ('dur', 4020): 411,
#  ('dur', 4030): 412,
#  ('dur', 4040): 413,
#  ('dur', 4050): 414,
#  ('dur', 4060): 415,
#  ('dur', 4070): 416,
#  ('dur', 4080): 417,
#  ('dur', 4090): 418,
#  ('dur', 4100): 419,
#  ('dur', 4110): 420,
#  ('dur', 4120): 421,
#  ('dur', 4130): 422,
#  ('dur', 4140): 423,
#  ('dur', 4150): 424,
#  ('dur', 4160): 425,
#  ('dur', 4170): 426,
#  ('dur', 4180): 427,
#  ('dur', 4190): 428,
#  ('dur', 4200): 429,
#  ('dur', 4210): 430,
#  ('dur', 4220): 431,
#  ('dur', 4230): 432,
#  ('dur', 4240): 433,
#  ('dur', 4250): 434,
#  ('dur', 4260): 435,
#  ('dur', 4270): 436,
#  ('dur', 4280): 437,
#  ('dur', 4290): 438,
#  ('dur', 4300): 439,
#  ('dur', 4310): 440,
#  ('dur', 4320): 441,
#  ('dur', 4330): 442,
#  ('dur', 4340): 443,
#  ('dur', 4350): 444,
#  ('dur', 4360): 445,
#  ('dur', 4370): 446,
#  ('dur', 4380): 447,
#  ('dur', 4390): 448,
#  ('dur', 4400): 449,
#  ('dur', 4410): 450,
#  ('dur', 4420): 451,
#  ('dur', 4430): 452,
#  ('dur', 4440): 453,
#  ('dur', 4450): 454,
#  ('dur', 4460): 455,
#  ('dur', 4470): 456,
#  ('dur', 4480): 457,
#  ('dur', 4490): 458,
#  ('dur', 4500): 459,
#  ('dur', 4510): 460,
#  ('dur', 4520): 461,
#  ('dur', 4530): 462,
#  ('dur', 4540): 463,
#  ('dur', 4550): 464,
#  ('dur', 4560): 465,
#  ('dur', 4570): 466,
#  ('dur', 4580): 467,
#  ('dur', 4590): 468,
#  ('dur', 4600): 469,
#  ('dur', 4610): 470,
#  ('dur', 4620): 471,
#  ('dur', 4630): 472,
#  ('dur', 4640): 473,
#  ('dur', 4650): 474,
#  ('dur', 4660): 475,
#  ('dur', 4670): 476,
#  ('dur', 4680): 477,
#  ('dur', 4690): 478,
#  ('dur', 4700): 479,
#  ('dur', 4710): 480,
#  ('dur', 4720): 481,
#  ('dur', 4730): 482,
#  ('dur', 4740): 483,
#  ('dur', 4750): 484,
#  ('dur', 4760): 485,
#  ('dur', 4770): 486,
#  ('dur', 4780): 487,
#  ('dur', 4790): 488,
#  ('dur', 4800): 489,
#  ('dur', 4810): 490,
#  ('dur', 4820): 491,
#  ('dur', 4830): 492,
#  ('dur', 4840): 493,
#  ('dur', 4850): 494,
#  ('dur', 4860): 495,
#  ('dur', 4870): 496,
#  ('dur', 4880): 497,
#  ('dur', 4890): 498,
#  ('dur', 4900): 499,
#  ('dur', 4910): 500,
#  ('dur', 4920): 501,
#  ('dur', 4930): 502,
#  ('dur', 4940): 503,
#  ('dur', 4950): 504,
#  ('dur', 4960): 505,
#  ('dur', 4970): 506,
#  ('dur', 4980): 507,
#  ('dur', 4990): 508,
#  ('dur', 5000): 509}
